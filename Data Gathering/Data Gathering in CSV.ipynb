# %% [markdown]
# <h1>Data Gathering with CSV
# </h1>

# %%
# !pip install pandas

# %% [markdown]
# <h2>Load Local Dataset </h2>

# %%
import pandas as pd

df=pd.read_csv("car data.csv")

df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %% [markdown]
# <h2>Load CSV From Website</h2>

# %%
import requests
from   io import StringIO

url=""
headers={ "User-Agent ": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:109.0) Gecko/20100101 Firefox/109.0"}
req=requests.get(url,headers=headers)
data=StringIO(req.text)

pd.read_csv(data)

# %% [markdown]
# ## Sep Parameter

# %%
data2=pd.read_csv("cars.tsv" , sep="\t")
data2
# Out:
#    year   make model      price                             comment  blank
# 0  2012  Tesla     S  80,000.65                                 NaN    NaN
# 1  1997   Ford  E350     35,000  Go get one now they are going fast    NaN
# 2  2015  Chevy  Volt   5,000.10                                 NaN    NaN

# %% [markdown]
# ## Add headings

# %%
# pd.read_csv(filename,names=[c1,c2,c3])

# %% [markdown]
# ## index_col parameter

# %%
data2=pd.read_csv("cars.tsv" , sep="\t",index_col='year')
data2
# Out:
#        make model      price                             comment  blank
# year
# 2012  Tesla     S  80,000.65                                 NaN    NaN
# 1997   Ford  E350     35,000  Go get one now they are going fast    NaN
# 2015  Chevy  Volt   5,000.10                                 NaN    NaN

# %% [markdown]
# ## header Parameter

# %%
# pd.read_csv (filename,header=index)

# %% [markdown]
# ## usecols parameter

# %% [markdown]
# df=pd.read_csv("car data.csv",usecols=['Car_Name','Year'])
#
# df

# %% [markdown]
# ## Squeeze paramater
# it change into series

# %%
df=pd.read_csv("car data.csv",usecols=['Car_Name'])
df.squeeze()
# Out:
# 0         ritz
# 1          sx4
# 2         ciaz
# 3      wagon r
# 4        swift
#         ...
# 296       city
# 297       brio
# 298       city
# 299       city
# 300       brio
# Name: Car_Name, Length: 301, dtype: object

# %% [markdown]
# ## Skip Rows/nrows

# %%
df=pd.read_csv("car data.csv",nrows=10,skiprows=[0,5])
df
# Out:
#             ritz  2014  3.35   5.59  27000  Petrol  Dealer  Manual  0
# 0            sx4  2013  4.75   9.54  43000  Diesel  Dealer  Manual  0
# 1           ciaz  2017  7.25   9.85   6900  Petrol  Dealer  Manual  0
# 2        wagon r  2011  2.85   4.15   5200  Petrol  Dealer  Manual  0
# 3  vitara brezza  2018  9.25   9.83   2071  Diesel  Dealer  Manual  0
# 4           ciaz  2015  6.75   8.12  18796  Petrol  Dealer  Manual  0
# 5        s cross  2015  6.50   8.61  33429  Diesel  Dealer  Manual  0
# 6           ciaz  2016  8.75   8.89  20273  Diesel  Dealer  Manual  0
# 7           ciaz  2015  7.45   8.92  42367  Diesel  Dealer  Manual  0
# 8       alto 800  2017  2.85   3.60   2135  Petrol  Dealer  Manual  0
# 9           ciaz  2015  6.85  10.38  51000  Diesel  Dealer  Manual  0

# %% [markdown]
# ## Encoding parameter
#
# ex: emoji

# %%
df=pd.read_csv("car data.csv",encoding="latin-1")
df

# %% [markdown]
# ## SKip Bad Lines

# %%
df=pd.read_csv("car data.csv",error_bad_lines=False)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df=pd.read_csv("car data.csv",error_bad_lines=False)
#       2 df
#
# TypeError: read_csv() got an unexpected keyword argument 'error_bad_lines'

# %% [markdown]
# ## dtypes Parameter

# %%
# pd.read_csv("car data.csv".dtype={'col':datatype})
pd.read_csv("car data.csv",dtype={'Owner':bool},nrows=10).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       10 non-null     object
#  1   Year           10 non-null     int64
#  2   Selling_Price  10 non-null     float64
#  3   Present_Price  10 non-null     float64
#  4   Driven_kms     10 non-null     int64
#  5   Fuel_Type      10 non-null     object
#  6   Selling_type   10 non-null     object
#  7   Transmission   10 non-null     object
#  8   Owner          10 non-null     bool
# dtypes: bool(1), float64(2), int64(2), object(4)
# memory usage: 782.0+ bytes

# %% [markdown]
# ## Handling Dates

# %%
pd.read_csv("matches.csv").info()
pd.read_csv("matches.csv",parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %% [markdown]
# ## Converters
# It is used to pass the function

# %%
def rename(name):
    if name=="Royal Challengers Bangalore":
        return 'RCB'
    else:
        return

# %%
pd.read_csv("matches.csv",converters={'team1':rename})
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %% [markdown]
# ## na_values parameter

# %%
pd.read_csv("matches.csv",na_values=['Royal Challengers Bangalore'],nrows=10)

# %% [markdown]
# ## Loading Huge dataset

# %%
import pandas as pd
defs=pd.read_csv('matches.csv',chunksize=100)

# %%
for chunks in defs:
    print(chunk.shape)
